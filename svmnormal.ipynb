# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Dataset
data = {
    'Hours': [1, 2, 3, 4, 5, 6, 7, 8],
    'Result': ['Fail', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass']
}

df = pd.DataFrame(data)

print(df)

# Features and target
X = df[['Hours']]
y = df['Result']

# SVM Model
svm = SVC(kernel='linear')
svm.fit(X, y)

pred=svm.predict(X)
print("Accuracy:",accuracy_score(y,pred))

# Prediction
new_data = pd.DataFrame({'Hours': [2.5, 6.5]})
prediction = svm.predict(new_data)

print("Prediction:", prediction)
# Out:
#    Hours Result
# 0      1   Fail
# 1      2   Fail
# 2      3   Fail
# 3      4   Pass
# 4      5   Pass
# 5      6   Pass
# 6      7   Pass
# 7      8   Pass
# Accuracy: 1.0
# Prediction: ['Fail' 'Pass']
