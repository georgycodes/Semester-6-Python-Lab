# %%
name=input("Enter the name:")
age=int(input("Enter the age:"))
print(f"The name is {name} and he is {age} years old")
# Out:
# Enter the name:Hafees
# Enter the age:21
# The name is Hafees and he is 21 years old
